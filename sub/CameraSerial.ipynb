# %%
import cv2
import numpy as np
import pickle

# %%
image = cv2.imread(r'C:\Users\Lenovo\Pictures\lenova.png')
cv2.imshow('Image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
webcam = cv2.VideoCapture(0)
webcam.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
webcam.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

if not webcam.isOpened():
    print("Could not open webcam !")
    exit()

while webcam.isOpened():
    status, frame = webcam.read()
    # 아래를 넣지 않으면 오류가 날 것이다.
    status, frame = cv2.imencode('.jpg', frame, [cv2.IMWRITE_JPEG_QUALITY, 90])
    shape = frame.shape
    print(str(shape))
    if status:
        data = pickle.dumps(frame)
        frame2 = pickle.loads(data)
        np_data = np.frombuffer(frame2, dtype='uint8')
        #frame3 = cv2.imdecode(frame2, cv2.IMREAD_COLOR)
        frame3 = cv2.imdecode(np_data, -1)
        if frame3 is None:
            print('frame3 is None !')
        else:
            #frame4 = cv2.resize(frame, (300,200))
            cv2.imshow("Frame", frame3)                     

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

webcam.release()
cv2.destroyAllWindows()
# Out:
# (10036,)
# (8773,)
# (9025,)
# (8621,)
# (8111,)
# (8720,)
# (9636,)
# (9881,)
# (10627,)
# (11521,)
# (11530,)
# (13823,)
# (14033,)
# (15727,)
# (16219,)
# (16051,)
# (17226,)
# (19352,)
# (19352,)
# (20201,)
# (19949,)
# (19949,)
# (19576,)
# (19576,)
# (19576,)
# (18921,)
# (18921,)
# (18921,)
# (19123,)
# (19123,)
# (19123,)
# (19486,)
# (19486,)
# (19486,)
# (20138,)
# (20138,)
# (20138,)
# (20373,)
# (20373,)
# (20608,)
# (20833,)
# (20833,)
# (20833,)
# (20976,)
# (20976,)
# (20976,)
# (21055,)
# (21055,)
# (21166,)
# (21241,)
# (21241,)
# (21241,)
# (21260,)
# (21260,)
# (21260,)
# (21307,)
# (21307,)
# (21307,)
# (21526,)
# (21526,)
# (21526,)
# (21510,)
# (21510,)
# (21510,)
# (21308,)
# (21308,)
# (21308,)
# (21385,)
# (21385,)
# (21385,)
# (21466,)
# (21466,)
# (21466,)
# (21588,)
# (21588,)
# (21588,)
# (21782,)
# (21782,)
# (21782,)
# (21668,)
# (21668,)
# (21668,)
# (21571,)
# (21571,)
# (21571,)
# (21571,)
# (21470,)
# (21470,)
# (21451,)
# (21451,)
# (21451,)
# ...
